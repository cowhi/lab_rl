# %%
import sys
import os
import glob
from IPython.display import Image

# %%
exp_list = sorted(glob.glob("/home/ruben/.lab/*"))
print(exp_list[-1])
#print(exp_list)
exp_content_list = sorted(glob.glob(os.path.join(exp_list[-1], "*")))
#print(exp_content_list)
#exp_plot_list = sorted(glob.glob(os.path.join(exp_list[-1], "run_00", "plots","*")))
exp_plot_list = sorted(glob.glob(os.path.join(exp_list[-1], "plots","*")))
#exp_plot_list = sorted(glob.glob(os.path.join("/home/ruben/.lab/2018-01-02_20-11_fungi_square_simpledqnagent", "run_00", "plots","*")))
#print(exp_plot_list)
graphs = []
for exp_plot in exp_plot_list:
    graphs.append(Image(exp_plot, width=400))
display(*graphs)
# Out:
# /home/ruben/.lab/2018-03-19_20-23_apple_square_simpledqnagent
